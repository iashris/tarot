# %%
import json
with open('tar.json','r') as f:
    data = json.load(f)
    f.close()

# %%
for card in data:
    name = card['name']
    #print(name)
    if 'of' in name and 'wheel':
        #minor
        name_elems=name.split(' of ')
        
    else:
        if " " in name:
            name_elems = name.split(" ")[-2:]
        else:
            name_elems = [name[0],name[1]]
    print(name_elems[0][0]+name_elems[1][0].upper())
# Out:
# TF
# TM
# HP
# TE
# TE
# TH
# TL
# TC
# ST
# TH
# WF
# JU
# HM
# DE
# TE
# TD
# TT
# TS
# TM
# TS
# JU
# TW
# KW
# QW
# KW
# PW
# TW
# NW
# EW
# SW
# SW
# FW
# FW
# TW
# TW
# AW
# KC
# QC
# KC
# PC
# TC
# NC
# EC
# SC
# SC
# FC
# FC
# TC
# TC
# AC
# KS
# QS
# KS
# PS
# TS
# NS
# ES
# SS
# SS
# FS
# FS
# TS
# TS
# AS
# KP
# QP
# KP
# PP
# TP
# NP
# EP
# SP
# SP
# FP
# FP
# TP
# TP
# AP
